# %% [markdown]
# # NDVI Analysis
# Calculate NDVI and summarize spatial vegetation conditions.

# %%
import numpy as np
from src.ndvi_processing import calculate_ndvi, summarize_ndvi

red = np.random.uniform(0.05, 0.5, (64, 64))
nir = np.random.uniform(0.2, 0.8, (64, 64))
ndvi = calculate_ndvi(nir, red)
print(summarize_ndvi(ndvi))
