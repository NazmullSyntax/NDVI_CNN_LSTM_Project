# %% [markdown]
# # CNN-LSTM Training
# Build and train the spatiotemporal forecasting model.

# %%
from src.cnn_lstm_model import build_cnn_lstm

model = build_cnn_lstm((6, 32, 32, 1), filters=32, units=64, horizon=1)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
